# %% [markdown]
# <a href="https://colab.research.google.com/github/YaKhom/ML-Practice/blob/main/GD_one_dimensional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Градиентный спуск для функции одной переменной

# %% [markdown]
# ## Импорт библиотек

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Практика

# %% [markdown]
# Найдем локальный минимум функции $f(x)=x^4-10x+3$ методом градиентного спуска.

# %% [markdown]
# Сначала определим функцию.

# %%
def f(x):
   return x**4 - 10*x + 3

# %% [markdown]
# Построим график функции.

# %%
x_values = [x for x in np.arange(-5, 5, 0.1)]
f_values = [f(x) for x in np.arange(-5, 5, 0.1)]

plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.plot(x_values, f_values);

# %% [markdown]
# Вычислим производную функции $f(x)$:
#
# $f'(x)=4x^3-10$.

# %%
def grad_f (x):
    return 4*(x**3) - 10

# %% [markdown]
# Теперь реализуем метод в виде функции.

# %%
def gradient_descent(x_start, learning_rate, epsilon, num_iterations):
    x_curr = x_start

    for i in range(num_iterations):
      x_new = x_curr - learning_rate * grad_f(x_curr)

      if abs(x_new - x_curr) < epsilon:
        return x_curr

      x_curr = x_new

    return x_curr

# %% [markdown]
# Попробуем стартовать из точки $x_0 = 5$ и идти с маленьким шагом $\eta = 0.01$.

# %%
x0 = 5
eta = 0.01
epsilon = 0.001
iterations = 10000

x_res = gradient_descent(x0, eta, epsilon, iterations)
x_res
# Out:
# 1.3536689167657399

# %% [markdown]
# Отметим найденную точку на графике.

# %%
plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.plot(x_values, f_values)

plt.scatter(x_res, f(x_res), marker='o', c='red');
